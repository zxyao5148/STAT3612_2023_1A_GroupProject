# %% [markdown]
# **Description:** This notebook demonstrates how to do timeseries classification using RNN models (Simple RNN, LSTM, and GRU).
#
# Reference: https://www.kaggle.com/code/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru/notebook

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd
import requests
from io import StringIO
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# combined data
# load processed data
train_mean = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_mean_mode.csv')
train_latest = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_latest.csv')
train_dispers = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_entropy_std.csv')
train_min = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_min.csv')
train_max = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_max.csv')
train_q1 = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_q1.csv')
train_q3 = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_q3.csv')
train_kurtosis = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_kurtosis.csv')
train_skewness = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_skewness.csv')
train_range = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_range.csv')
train_iqr = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_iqr.csv')
train_latest = train_latest.drop(train_latest.columns[0:13], axis=1)
train_dispers = train_dispers.drop(train_dispers.columns[0:13], axis=1)
train_min = train_min.drop(train_min.columns[0:13], axis=1)
train_max = train_max.drop(train_max.columns[0:13], axis=1)
train_q1 = train_q1.drop(train_q1.columns[0:13], axis=1)
train_q3 = train_q3.drop(train_q3.columns[0:13], axis=1)
train_kurtois = train_kurtosis.drop(train_kurtosis.columns[0:13], axis=1)
train_skewness = train_skewness.drop(train_skewness.columns[0:13], axis=1)
train_range = train_range.drop(train_range.columns[0:13], axis=1)
train_iqr = train_iqr.drop(train_iqr.columns[0:13], axis=1)

# merge train_ and train_latest
train = pd.concat([train_mean, train_latest, train_dispers, train_min, train_max], axis=1)

# load processed data
test_mean = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_mean_mode.csv')
test_latest = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_latest.csv')
test_dispers = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_entropy_std.csv')
test_min = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_min.csv')
test_max = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_max.csv')
test_q1 = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_q1.csv')
test_q3 = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_q3.csv')
test_kurtosis = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_kurtosis.csv')
test_skewness = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_skewness.csv')
test_range = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_range.csv')
test_iqr = pd.read_csv('https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_iqr.csv')
test_latest = test_latest.drop(test_latest.columns[0:12], axis=1)
test_dispers = test_dispers.drop(test_dispers.columns[0:12], axis=1)
test_min = test_min.drop(test_min.columns[0:12], axis=1)
test_max = test_max.drop(test_max.columns[0:12], axis=1)
test_q1 = test_q1.drop(test_q1.columns[0:12], axis=1)
test_q3 = test_q3.drop(test_q3.columns[0:12], axis=1)
test_kurtosis = test_kurtosis.drop(test_kurtosis.columns[0:12], axis=1)
test_skewness = test_skewness.drop(test_skewness.columns[0:12], axis=1)
test_range = test_range.drop(test_range.columns[0:12], axis=1)
test_iqr = test_iqr.drop(test_iqr.columns[0:12], axis=1)

# merge train_mean and train_latest
test = pd.concat([test_mean, test_latest, test_dispers, test_min, test_max], axis=1)

# %%
train = train.drop(train.columns[11], axis=1)
test = test.drop(test.columns[11], axis=1)

# %%
x_train = pd.concat([train.iloc[:,10], train.iloc[:,12:]], axis=1)
y_train = train.iloc[:,11]

# !wget https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/code_base/adjust_imbl.py
from adjust_imbl import adjust_imbl
x_train, y_train = adjust_imbl(x_train, y_train)

# with 80% of the data for training and 20% for validation
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, random_state=3612)

x_test = test.iloc[:,10:]
# Out:
# --2023-12-05 04:53:09--  https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/code_base/adjust_imbl.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 927 [text/plain]
# Saving to: ‘adjust_imbl.py’
#
# adjust_imbl.py      100%[===================>]     927  --.-KB/s    in 0s
#
# 2023-12-05 04:53:09 (24.0 MB/s) - ‘adjust_imbl.py’ saved [927/927]
#
# Original dataset shape Counter({0: 9564, 1: 2032})
# Resampled dataset shape Counter({0: 2032, 1: 2032})

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pca = PCA(n_components=150)  # You can specify the number of components to reduce to
scaler = StandardScaler()

# Fit and transform the scaler on the training data
x_train_scaled = scaler.fit_transform(x_train)

# Fit PCA on the scaled training data
pca.fit(x_train_scaled)

# Transform the training, validation, and test data using the fitted PCA and scaler
x_train = pca.transform(x_train_scaled)
x_valid_scaled = scaler.transform(x_valid)
x_valid = pca.transform(x_valid_scaled)
x_test_scaled = scaler.transform(x_test)
x_test = pca.transform(x_test_scaled)

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_valid = x_valid.reshape((x_valid.shape[0], x_valid.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# Reset the index of the y_train DataFrame
y_train = y_train.reset_index(drop=True)

# Shuffle the indices
idx = np.random.permutation(len(x_train))

# Reassign the values using the shuffled indices
x_train = x_train[idx]
y_train = y_train.iloc[idx]

# %% [markdown]
# ## Build the model
#
# The model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.

# %%
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, GRU, SimpleRNN, Bidirectional
from keras.models import Sequential
import keras
from keras.optimizers import Adam
from keras.layers import BatchNormalization
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# #  Bidirectional GRU

# %%
from sklearn.metrics import roc_auc_score
import tensorflow as tf

# Define a custom metric function to calculate AUC
def auc(y_true, y_pred):
    auc = tf.py_function(roc_auc_score, (y_true, y_pred), tf.float32)
    return auc

model = Sequential()
# Add a Bidirectional GRU layer with return_sequences=True and L2 regularization
model.add(Bidirectional(GRU(64, return_sequences=True, input_shape=(x_train.shape[1], 1), kernel_regularizer=l2(0.01))))
# Add Batch Normalization
model.add(BatchNormalization())
model.add(Dropout(0.3))
# Add another Bidirectional GRU layer with return_sequences=False and activation function set to "tanh"
model.add(Bidirectional(GRU(128, return_sequences=False, activation="tanh", kernel_regularizer=l2(0.01))))
# Add Batch Normalization
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(1, activation="sigmoid"))

# Compile the model with a lower learning rate and use ReduceLROnPlateau for learning rate scheduling
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=1e-4), metrics=["accuracy", auc])

print('model compiled')

# Define early stopping and learning rate reduction callbacks
callbacks = [EarlyStopping(patience=10, restore_best_weights=True), ReduceLROnPlateau(factor=0.1, patience=5)]

# Print model summary
#print(model.summary())

# Train the model with a smaller batch size
history_GRU = model.fit(x_train, y_train, batch_size=128, epochs=300, validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# model compiled
# Epoch 1/300
# 26/26 [==============================] - 20s 96ms/step - loss: 4.6127 - accuracy: 0.5703 - auc: 0.5885 - val_loss: 4.4110 - val_accuracy: 0.6519 - val_auc: 0.6929 - lr: 1.0000e-04
# Epoch 2/300
# 26/26 [==============================] - 1s 38ms/step - loss: 4.3837 - accuracy: 0.6106 - auc: 0.6468 - val_loss: 4.2449 - val_accuracy: 0.6138 - val_auc: 0.6696 - lr: 1.0000e-04
# Epoch 3/300
# 26/26 [==============================] - 1s 44ms/step - loss: 4.2403 - accuracy: 0.6017 - auc: 0.6384 - val_loss: 4.0853 - val_accuracy: 0.5990 - val_auc: 0.6782 - lr: 1.0000e-04
# Epoch 4/300
# 26/26 [==============================] - 1s 42ms/step - loss: 4.0614 - accuracy: 0.6078 - auc: 0.6522 - val_loss: 3.9345 - val_accuracy: 0.5683 - val_auc: 0.6662 - lr: 1.0000e-04
# Epoch 5/300
# 26/26 [==============================] - 1s 42ms/step - loss: 3.9095 - accuracy: 0.6183 - auc: 0.6585 - val_loss: 3.7911 - val_accuracy: 0.5609 - val_auc: 0.6686 - lr: 1.0000e-04
# Epoch 6/300
# 26/26 [==============================] - 1s 38ms/step - loss: 3.7714 - accuracy: 0.6081 - auc: 0.6517 - val_loss: 3.6529 - val_accuracy: 0.5646 - val_auc: 0.6627 - lr: 1.0000e-04
# Epoch 7/300
# 26/26 [==============================] - 1s 38ms/step - loss: 3.6224 - accuracy: 0.6263 - auc: 0.6686 - val_loss: 3.5184 - val_accuracy: 0.5769 - val_auc: 0.6807 - lr: 1.0000e-04
# Epoch 8/300
# 26/26 [==============================] - 1s 37ms/step - loss: 3.4844 - accuracy: 0.6275 - auc: 0.6745 - val_loss: 3.3916 - val_accuracy: 0.5806 - val_auc: 0.6843 - lr: 1.0000e-04
# Epoch 9/300
# 26/26 [==============================] - 1s 39ms/step - loss: 3.3723 - accuracy: 0.6173 - auc: 0.6682 - val_loss: 3.2740 - val_accuracy: 0.5806 - val_auc: 0.6870 - lr: 1.0000e-04
# Epoch 10/300
# 26/26 [==============================] - 1s 39ms/step - loss: 3.2497 - accuracy: 0.6281 - auc: 0.6814 - val_loss: 3.1543 - val_accuracy: 0.6015 - val_auc: 0.7019 - lr: 1.0000e-04
# Epoch 11/300
# 26/26 [==============================] - 1s 39ms/step - loss: 3.1499 - accuracy: 0.6137 - auc: 0.6669 - val_loss: 3.0486 - val_accuracy: 0.5978 - val_auc: 0.7007 - lr: 1.0000e-04
# Epoch 12/300
# 26/26 [==============================] - 1s 39ms/step - loss: 3.0331 - accuracy: 0.6290 - auc: 0.6773 - val_loss: 2.9405 - val_accuracy: 0.6027 - val_auc: 0.7048 - lr: 1.0000e-04
# Epoch 13/300
# 26/26 [==============================] - 1s 39ms/step - loss: 2.9286 - accuracy: 0.6287 - auc: 0.6805 - val_loss: 2.8338 - val_accuracy: 0.6261 - val_auc: 0.7226 - lr: 1.0000e-04
# Epoch 14/300
# 26/26 [==============================] - 1s 40ms/step - loss: 2.8325 - accuracy: 0.6364 - auc: 0.6870 - val_loss: 2.7429 - val_accuracy: 0.6236 - val_auc: 0.7166 - lr: 1.0000e-04
# Epoch 15/300
# 26/26 [==============================] - 1s 38ms/step - loss: 2.7429 - accuracy: 0.6370 - auc: 0.6804 - val_loss: 2.6431 - val_accuracy: 0.6470 - val_auc: 0.7298 - lr: 1.0000e-04
# Epoch 16/300
# 26/26 [==============================] - 1s 43ms/step - loss: 2.6565 - accuracy: 0.6389 - auc: 0.6920 - val_loss: 2.5648 - val_accuracy: 0.6335 - val_auc: 0.7224 - lr: 1.0000e-04
# Epoch 17/300
# 26/26 [==============================] - 1s 44ms/step - loss: 2.5876 - accuracy: 0.6284 - auc: 0.6779 - val_loss: 2.4765 - val_accuracy: 0.6458 - val_auc: 0.7283 - lr: 1.0000e-04
# Epoch 18/300
# 26/26 [==============================] - 1s 42ms/step - loss: 2.4869 - accuracy: 0.6398 - auc: 0.6940 - val_loss: 2.3931 - val_accuracy: 0.6482 - val_auc: 0.7355 - lr: 1.0000e-04
# Epoch 19/300
# 26/26 [==============================] - 1s 38ms/step - loss: 2.4136 - accuracy: 0.6432 - auc: 0.6982 - val_loss: 2.3121 - val_accuracy: 0.6691 - val_auc: 0.7429 - lr: 1.0000e-04
# Epoch 20/300
# 26/26 [==============================] - 1s 38ms/step - loss: 2.3551 - accuracy: 0.6386 - auc: 0.6872 - val_loss: 2.2438 - val_accuracy: 0.6753 - val_auc: 0.7425 - lr: 1.0000e-04
# Epoch 21/300
# 26/26 [==============================] - 1s 40ms/step - loss: 2.2851 - accuracy: 0.6383 - auc: 0.6940 - val_loss: 2.1788 - val_accuracy: 0.6704 - val_auc: 0.7424 - lr: 1.0000e-04
# Epoch 22/300
# 26/26 [==============================] - 1s 40ms/step - loss: 2.2227 - accuracy: 0.6247 - auc: 0.6916 - val_loss: 2.1190 - val_accuracy: 0.6765 - val_auc: 0.7436 - lr: 1.0000e-04
# Epoch 23/300
# 26/26 [==============================] - 1s 40ms/step - loss: 2.1588 - accuracy: 0.6333 - auc: 0.6971 - val_loss: 2.0555 - val_accuracy: 0.6925 - val_auc: 0.7465 - lr: 1.0000e-04
# Epoch 24/300
# 26/26 [==============================] - 1s 38ms/step - loss: 2.1015 - accuracy: 0.6410 - auc: 0.6952 - val_loss: 2.0028 - val_accuracy: 0.6777 - val_auc: 0.7404 - lr: 1.0000e-04
# Epoch 25/300
# 26/26 [==============================] - 1s 41ms/step - loss: 2.0455 - accuracy: 0.6376 - auc: 0.6965 - val_loss: 1.9480 - val_accuracy: 0.6863 - val_auc: 0.7446 - lr: 1.0000e-04
# Epoch 26/300
# 26/26 [==============================] - 1s 38ms/step - loss: 2.0035 - accuracy: 0.6407 - auc: 0.6885 - val_loss: 1.8969 - val_accuracy: 0.6925 - val_auc: 0.7475 - lr: 1.0000e-04
# Epoch 27/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.9596 - accuracy: 0.6303 - auc: 0.6807 - val_loss: 1.8529 - val_accuracy: 0.6863 - val_auc: 0.7444 - lr: 1.0000e-04
# Epoch 28/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.9019 - accuracy: 0.6416 - auc: 0.6936 - val_loss: 1.7981 - val_accuracy: 0.6962 - val_auc: 0.7559 - lr: 1.0000e-04
# Epoch 29/300
# 26/26 [==============================] - 1s 44ms/step - loss: 1.8672 - accuracy: 0.6333 - auc: 0.6912 - val_loss: 1.7625 - val_accuracy: 0.6851 - val_auc: 0.7495 - lr: 1.0000e-04
# Epoch 30/300
# 26/26 [==============================] - 1s 41ms/step - loss: 1.8217 - accuracy: 0.6269 - auc: 0.6905 - val_loss: 1.7174 - val_accuracy: 0.6925 - val_auc: 0.7530 - lr: 1.0000e-04
# Epoch 31/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.7647 - accuracy: 0.6469 - auc: 0.7044 - val_loss: 1.6781 - val_accuracy: 0.6900 - val_auc: 0.7562 - lr: 1.0000e-04
# Epoch 32/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.7273 - accuracy: 0.6493 - auc: 0.7069 - val_loss: 1.6386 - val_accuracy: 0.6888 - val_auc: 0.7569 - lr: 1.0000e-04
# Epoch 33/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.7006 - accuracy: 0.6380 - auc: 0.6956 - val_loss: 1.6057 - val_accuracy: 0.6913 - val_auc: 0.7561 - lr: 1.0000e-04
# Epoch 34/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.6523 - accuracy: 0.6527 - auc: 0.7131 - val_loss: 1.5736 - val_accuracy: 0.6888 - val_auc: 0.7547 - lr: 1.0000e-04
# Epoch 35/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.6306 - accuracy: 0.6475 - auc: 0.7024 - val_loss: 1.5401 - val_accuracy: 0.6876 - val_auc: 0.7520 - lr: 1.0000e-04
# Epoch 36/300
# 26/26 [==============================] - 1s 53ms/step - loss: 1.5911 - accuracy: 0.6478 - auc: 0.7064 - val_loss: 1.5147 - val_accuracy: 0.6937 - val_auc: 0.7543 - lr: 1.0000e-04
# Epoch 37/300
# 26/26 [==============================] - 1s 55ms/step - loss: 1.5606 - accuracy: 0.6509 - auc: 0.7069 - val_loss: 1.4782 - val_accuracy: 0.6950 - val_auc: 0.7563 - lr: 1.0000e-04
# Epoch 38/300
# 26/26 [==============================] - 1s 54ms/step - loss: 1.5497 - accuracy: 0.6466 - auc: 0.6928 - val_loss: 1.4547 - val_accuracy: 0.6950 - val_auc: 0.7528 - lr: 1.0000e-04
# Epoch 39/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.5035 - accuracy: 0.6515 - auc: 0.7104 - val_loss: 1.4249 - val_accuracy: 0.6925 - val_auc: 0.7559 - lr: 1.0000e-04
# Epoch 40/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.4761 - accuracy: 0.6530 - auc: 0.7134 - val_loss: 1.4052 - val_accuracy: 0.7011 - val_auc: 0.7551 - lr: 1.0000e-04
# Epoch 41/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.4543 - accuracy: 0.6475 - auc: 0.7065 - val_loss: 1.3763 - val_accuracy: 0.6950 - val_auc: 0.7566 - lr: 1.0000e-04
# Epoch 42/300
# 26/26 [==============================] - 1s 44ms/step - loss: 1.4368 - accuracy: 0.6503 - auc: 0.7046 - val_loss: 1.3552 - val_accuracy: 0.6962 - val_auc: 0.7550 - lr: 1.0000e-04
# Epoch 43/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.4166 - accuracy: 0.6478 - auc: 0.6987 - val_loss: 1.3325 - val_accuracy: 0.7011 - val_auc: 0.7581 - lr: 1.0000e-04
# Epoch 44/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.3874 - accuracy: 0.6503 - auc: 0.7044 - val_loss: 1.3205 - val_accuracy: 0.7036 - val_auc: 0.7508 - lr: 1.0000e-04
# Epoch 45/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.3642 - accuracy: 0.6466 - auc: 0.7116 - val_loss: 1.2938 - val_accuracy: 0.7011 - val_auc: 0.7570 - lr: 1.0000e-04
# Epoch 46/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.3387 - accuracy: 0.6540 - auc: 0.7168 - val_loss: 1.2737 - val_accuracy: 0.7060 - val_auc: 0.7583 - lr: 1.0000e-04
# Epoch 47/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.3202 - accuracy: 0.6620 - auc: 0.7157 - val_loss: 1.2516 - val_accuracy: 0.6974 - val_auc: 0.7626 - lr: 1.0000e-04
# Epoch 48/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.3088 - accuracy: 0.6518 - auc: 0.7065 - val_loss: 1.2383 - val_accuracy: 0.6925 - val_auc: 0.7605 - lr: 1.0000e-04
# Epoch 49/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.2913 - accuracy: 0.6413 - auc: 0.7075 - val_loss: 1.2195 - val_accuracy: 0.6937 - val_auc: 0.7617 - lr: 1.0000e-04
# Epoch 50/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.2776 - accuracy: 0.6469 - auc: 0.7020 - val_loss: 1.2000 - val_accuracy: 0.6999 - val_auc: 0.7639 - lr: 1.0000e-04
# Epoch 51/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.2520 - accuracy: 0.6540 - auc: 0.7113 - val_loss: 1.1803 - val_accuracy: 0.7023 - val_auc: 0.7651 - lr: 1.0000e-04
# Epoch 52/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.2320 - accuracy: 0.6672 - auc: 0.7184 - val_loss: 1.1719 - val_accuracy: 0.7159 - val_auc: 0.7582 - lr: 1.0000e-04
# Epoch 53/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.2093 - accuracy: 0.6684 - auc: 0.7260 - val_loss: 1.1545 - val_accuracy: 0.6999 - val_auc: 0.7645 - lr: 1.0000e-04
# Epoch 54/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.1901 - accuracy: 0.6703 - auc: 0.7256 - val_loss: 1.1390 - val_accuracy: 0.7036 - val_auc: 0.7659 - lr: 1.0000e-04
# Epoch 55/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.1834 - accuracy: 0.6647 - auc: 0.7185 - val_loss: 1.1257 - val_accuracy: 0.7060 - val_auc: 0.7674 - lr: 1.0000e-04
# Epoch 56/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.1725 - accuracy: 0.6549 - auc: 0.7203 - val_loss: 1.1145 - val_accuracy: 0.7011 - val_auc: 0.7632 - lr: 1.0000e-04
# Epoch 57/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.1670 - accuracy: 0.6524 - auc: 0.7093 - val_loss: 1.1019 - val_accuracy: 0.7097 - val_auc: 0.7655 - lr: 1.0000e-04
# Epoch 58/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.1491 - accuracy: 0.6518 - auc: 0.7164 - val_loss: 1.0879 - val_accuracy: 0.7048 - val_auc: 0.7674 - lr: 1.0000e-04
# Epoch 59/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.1336 - accuracy: 0.6681 - auc: 0.7227 - val_loss: 1.0764 - val_accuracy: 0.7036 - val_auc: 0.7658 - lr: 1.0000e-04
# Epoch 60/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.1331 - accuracy: 0.6515 - auc: 0.7108 - val_loss: 1.0672 - val_accuracy: 0.7060 - val_auc: 0.7666 - lr: 1.0000e-04
# Epoch 61/300
# 26/26 [==============================] - 1s 39ms/step - loss: 1.1076 - accuracy: 0.6675 - auc: 0.7294 - val_loss: 1.0562 - val_accuracy: 0.7036 - val_auc: 0.7687 - lr: 1.0000e-04
# Epoch 62/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.1010 - accuracy: 0.6659 - auc: 0.7233 - val_loss: 1.0425 - val_accuracy: 0.7122 - val_auc: 0.7695 - lr: 1.0000e-04
# Epoch 63/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.0895 - accuracy: 0.6607 - auc: 0.7233 - val_loss: 1.0310 - val_accuracy: 0.7060 - val_auc: 0.7725 - lr: 1.0000e-04
# Epoch 64/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.0867 - accuracy: 0.6573 - auc: 0.7194 - val_loss: 1.0221 - val_accuracy: 0.7085 - val_auc: 0.7719 - lr: 1.0000e-04
# Epoch 65/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.0714 - accuracy: 0.6684 - auc: 0.7222 - val_loss: 1.0124 - val_accuracy: 0.7220 - val_auc: 0.7712 - lr: 1.0000e-04
# Epoch 66/300
# 26/26 [==============================] - 1s 38ms/step - loss: 1.0663 - accuracy: 0.6641 - auc: 0.7193 - val_loss: 1.0053 - val_accuracy: 0.7085 - val_auc: 0.7704 - lr: 1.0000e-04
# Epoch 67/300
# 26/26 [==============================] - 1s 52ms/step - loss: 1.0512 - accuracy: 0.6647 - auc: 0.7229 - val_loss: 0.9949 - val_accuracy: 0.7196 - val_auc: 0.7664 - lr: 1.0000e-04
# Epoch 68/300
# 26/26 [==============================] - 1s 43ms/step - loss: 1.0409 - accuracy: 0.6604 - auc: 0.7238 - val_loss: 0.9848 - val_accuracy: 0.7109 - val_auc: 0.7720 - lr: 1.0000e-04
# Epoch 69/300
# 26/26 [==============================] - 1s 42ms/step - loss: 1.0258 - accuracy: 0.6644 - auc: 0.7324 - val_loss: 0.9796 - val_accuracy: 0.7257 - val_auc: 0.7699 - lr: 1.0000e-04
# Epoch 70/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.0224 - accuracy: 0.6718 - auc: 0.7280 - val_loss: 0.9687 - val_accuracy: 0.7208 - val_auc: 0.7716 - lr: 1.0000e-04
# Epoch 71/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.0181 - accuracy: 0.6536 - auc: 0.7145 - val_loss: 0.9604 - val_accuracy: 0.7134 - val_auc: 0.7694 - lr: 1.0000e-04
# Epoch 72/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.9961 - accuracy: 0.6749 - auc: 0.7391 - val_loss: 0.9564 - val_accuracy: 0.7232 - val_auc: 0.7686 - lr: 1.0000e-04
# Epoch 73/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.9925 - accuracy: 0.6681 - auc: 0.7378 - val_loss: 0.9451 - val_accuracy: 0.7146 - val_auc: 0.7714 - lr: 1.0000e-04
# Epoch 74/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.9770 - accuracy: 0.6675 - auc: 0.7385 - val_loss: 0.9385 - val_accuracy: 0.7355 - val_auc: 0.7708 - lr: 1.0000e-04
# Epoch 75/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.9881 - accuracy: 0.6607 - auc: 0.7271 - val_loss: 0.9317 - val_accuracy: 0.7146 - val_auc: 0.7711 - lr: 1.0000e-04
# Epoch 76/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.9771 - accuracy: 0.6672 - auc: 0.7270 - val_loss: 0.9281 - val_accuracy: 0.7208 - val_auc: 0.7694 - lr: 1.0000e-04
# Epoch 77/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.9569 - accuracy: 0.6638 - auc: 0.7347 - val_loss: 0.9136 - val_accuracy: 0.7220 - val_auc: 0.7706 - lr: 1.0000e-04
# Epoch 78/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.9541 - accuracy: 0.6675 - auc: 0.7367 - val_loss: 0.9115 - val_accuracy: 0.7171 - val_auc: 0.7690 - lr: 1.0000e-04
# Epoch 79/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.9471 - accuracy: 0.6779 - auc: 0.7358 - val_loss: 0.8979 - val_accuracy: 0.7171 - val_auc: 0.7743 - lr: 1.0000e-04
# Epoch 80/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.9474 - accuracy: 0.6675 - auc: 0.7285 - val_loss: 0.8921 - val_accuracy: 0.7208 - val_auc: 0.7735 - lr: 1.0000e-04
# Epoch 81/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.9328 - accuracy: 0.6770 - auc: 0.7315 - val_loss: 0.8921 - val_accuracy: 0.7196 - val_auc: 0.7720 - lr: 1.0000e-04
# Epoch 82/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.9256 - accuracy: 0.6755 - auc: 0.7392 - val_loss: 0.8809 - val_accuracy: 0.7183 - val_auc: 0.7763 - lr: 1.0000e-04
# Epoch 83/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.9229 - accuracy: 0.6739 - auc: 0.7358 - val_loss: 0.8785 - val_accuracy: 0.7257 - val_auc: 0.7722 - lr: 1.0000e-04
# Epoch 84/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.9131 - accuracy: 0.6712 - auc: 0.7353 - val_loss: 0.8705 - val_accuracy: 0.7208 - val_auc: 0.7731 - lr: 1.0000e-04
# Epoch 85/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.9121 - accuracy: 0.6709 - auc: 0.7345 - val_loss: 0.8649 - val_accuracy: 0.7220 - val_auc: 0.7755 - lr: 1.0000e-04
# Epoch 86/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.8988 - accuracy: 0.6678 - auc: 0.7409 - val_loss: 0.8599 - val_accuracy: 0.7208 - val_auc: 0.7760 - lr: 1.0000e-04
# Epoch 87/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.8985 - accuracy: 0.6718 - auc: 0.7396 - val_loss: 0.8551 - val_accuracy: 0.7122 - val_auc: 0.7739 - lr: 1.0000e-04
# Epoch 88/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.8908 - accuracy: 0.6752 - auc: 0.7379 - val_loss: 0.8479 - val_accuracy: 0.7196 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 89/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.8907 - accuracy: 0.6727 - auc: 0.7355 - val_loss: 0.8466 - val_accuracy: 0.7183 - val_auc: 0.7719 - lr: 1.0000e-04
# Epoch 90/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.8813 - accuracy: 0.6739 - auc: 0.7371 - val_loss: 0.8419 - val_accuracy: 0.7196 - val_auc: 0.7694 - lr: 1.0000e-04
# Epoch 91/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.8805 - accuracy: 0.6773 - auc: 0.7348 - val_loss: 0.8398 - val_accuracy: 0.7109 - val_auc: 0.7706 - lr: 1.0000e-04
# Epoch 92/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.8757 - accuracy: 0.6770 - auc: 0.7403 - val_loss: 0.8358 - val_accuracy: 0.7220 - val_auc: 0.7687 - lr: 1.0000e-04
# Epoch 93/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.8698 - accuracy: 0.6746 - auc: 0.7363 - val_loss: 0.8337 - val_accuracy: 0.7085 - val_auc: 0.7703 - lr: 1.0000e-04
# Epoch 94/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.8558 - accuracy: 0.6776 - auc: 0.7464 - val_loss: 0.8199 - val_accuracy: 0.7171 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 95/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.8595 - accuracy: 0.6715 - auc: 0.7393 - val_loss: 0.8187 - val_accuracy: 0.7171 - val_auc: 0.7714 - lr: 1.0000e-04
# Epoch 96/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.8690 - accuracy: 0.6613 - auc: 0.7258 - val_loss: 0.8218 - val_accuracy: 0.7097 - val_auc: 0.7701 - lr: 1.0000e-04
# Epoch 97/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.8511 - accuracy: 0.6810 - auc: 0.7386 - val_loss: 0.8102 - val_accuracy: 0.7122 - val_auc: 0.7731 - lr: 1.0000e-04
# Epoch 98/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.8416 - accuracy: 0.6696 - auc: 0.7411 - val_loss: 0.8079 - val_accuracy: 0.7282 - val_auc: 0.7693 - lr: 1.0000e-04
# Epoch 99/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.8391 - accuracy: 0.6730 - auc: 0.7362 - val_loss: 0.8045 - val_accuracy: 0.7196 - val_auc: 0.7698 - lr: 1.0000e-04
# Epoch 100/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.8355 - accuracy: 0.6773 - auc: 0.7411 - val_loss: 0.7974 - val_accuracy: 0.7097 - val_auc: 0.7724 - lr: 1.0000e-04
# Epoch 101/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.8312 - accuracy: 0.6758 - auc: 0.7396 - val_loss: 0.7935 - val_accuracy: 0.7208 - val_auc: 0.7718 - lr: 1.0000e-04
# Epoch 102/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.8302 - accuracy: 0.6681 - auc: 0.7357 - val_loss: 0.7897 - val_accuracy: 0.7171 - val_auc: 0.7735 - lr: 1.0000e-04
# Epoch 103/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.8213 - accuracy: 0.6709 - auc: 0.7368 - val_loss: 0.7850 - val_accuracy: 0.7171 - val_auc: 0.7727 - lr: 1.0000e-04
# Epoch 104/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.8252 - accuracy: 0.6687 - auc: 0.7347 - val_loss: 0.7819 - val_accuracy: 0.7122 - val_auc: 0.7719 - lr: 1.0000e-04
# Epoch 105/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.8215 - accuracy: 0.6706 - auc: 0.7325 - val_loss: 0.7768 - val_accuracy: 0.7220 - val_auc: 0.7715 - lr: 1.0000e-04
# Epoch 106/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.8130 - accuracy: 0.6813 - auc: 0.7425 - val_loss: 0.7738 - val_accuracy: 0.7220 - val_auc: 0.7683 - lr: 1.0000e-04
# Epoch 107/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.8051 - accuracy: 0.6724 - auc: 0.7377 - val_loss: 0.7708 - val_accuracy: 0.7232 - val_auc: 0.7713 - lr: 1.0000e-04
# Epoch 108/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.8039 - accuracy: 0.6730 - auc: 0.7410 - val_loss: 0.7692 - val_accuracy: 0.7196 - val_auc: 0.7713 - lr: 1.0000e-04
# Epoch 109/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7998 - accuracy: 0.6832 - auc: 0.7409 - val_loss: 0.7637 - val_accuracy: 0.7011 - val_auc: 0.7729 - lr: 1.0000e-04
# Epoch 110/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7870 - accuracy: 0.6823 - auc: 0.7505 - val_loss: 0.7645 - val_accuracy: 0.7085 - val_auc: 0.7653 - lr: 1.0000e-04
# Epoch 111/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7884 - accuracy: 0.6829 - auc: 0.7462 - val_loss: 0.7577 - val_accuracy: 0.7146 - val_auc: 0.7732 - lr: 1.0000e-04
# Epoch 112/300
# 26/26 [==============================] - 1s 37ms/step - loss: 0.7865 - accuracy: 0.6810 - auc: 0.7458 - val_loss: 0.7552 - val_accuracy: 0.7257 - val_auc: 0.7690 - lr: 1.0000e-04
# Epoch 113/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7779 - accuracy: 0.6872 - auc: 0.7501 - val_loss: 0.7521 - val_accuracy: 0.7159 - val_auc: 0.7722 - lr: 1.0000e-04
# Epoch 114/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7806 - accuracy: 0.6755 - auc: 0.7432 - val_loss: 0.7513 - val_accuracy: 0.7159 - val_auc: 0.7709 - lr: 1.0000e-04
# Epoch 115/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7700 - accuracy: 0.6887 - auc: 0.7561 - val_loss: 0.7461 - val_accuracy: 0.7171 - val_auc: 0.7734 - lr: 1.0000e-04
# Epoch 116/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7720 - accuracy: 0.6829 - auc: 0.7502 - val_loss: 0.7423 - val_accuracy: 0.7232 - val_auc: 0.7706 - lr: 1.0000e-04
# Epoch 117/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7773 - accuracy: 0.6795 - auc: 0.7398 - val_loss: 0.7383 - val_accuracy: 0.7269 - val_auc: 0.7729 - lr: 1.0000e-04
# Epoch 118/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7656 - accuracy: 0.6730 - auc: 0.7453 - val_loss: 0.7388 - val_accuracy: 0.7208 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 119/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.7604 - accuracy: 0.6795 - auc: 0.7550 - val_loss: 0.7358 - val_accuracy: 0.7257 - val_auc: 0.7693 - lr: 1.0000e-04
# Epoch 120/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.7597 - accuracy: 0.6890 - auc: 0.7466 - val_loss: 0.7295 - val_accuracy: 0.7171 - val_auc: 0.7708 - lr: 1.0000e-04
# Epoch 121/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7538 - accuracy: 0.6856 - auc: 0.7441 - val_loss: 0.7354 - val_accuracy: 0.7036 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 122/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7534 - accuracy: 0.6884 - auc: 0.7543 - val_loss: 0.7238 - val_accuracy: 0.7220 - val_auc: 0.7729 - lr: 1.0000e-04
# Epoch 123/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7467 - accuracy: 0.6902 - auc: 0.7519 - val_loss: 0.7283 - val_accuracy: 0.7122 - val_auc: 0.7707 - lr: 1.0000e-04
# Epoch 124/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7471 - accuracy: 0.6856 - auc: 0.7500 - val_loss: 0.7209 - val_accuracy: 0.7269 - val_auc: 0.7690 - lr: 1.0000e-04
# Epoch 125/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7397 - accuracy: 0.6906 - auc: 0.7544 - val_loss: 0.7205 - val_accuracy: 0.7257 - val_auc: 0.7657 - lr: 1.0000e-04
# Epoch 126/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7475 - accuracy: 0.6823 - auc: 0.7457 - val_loss: 0.7213 - val_accuracy: 0.7146 - val_auc: 0.7713 - lr: 1.0000e-04
# Epoch 127/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7403 - accuracy: 0.6844 - auc: 0.7441 - val_loss: 0.7157 - val_accuracy: 0.7134 - val_auc: 0.7703 - lr: 1.0000e-04
# Epoch 128/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7376 - accuracy: 0.6899 - auc: 0.7540 - val_loss: 0.7052 - val_accuracy: 0.7319 - val_auc: 0.7750 - lr: 1.0000e-04
# Epoch 129/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7336 - accuracy: 0.6893 - auc: 0.7548 - val_loss: 0.7094 - val_accuracy: 0.7159 - val_auc: 0.7713 - lr: 1.0000e-04
# Epoch 130/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.7320 - accuracy: 0.6884 - auc: 0.7524 - val_loss: 0.7057 - val_accuracy: 0.7232 - val_auc: 0.7696 - lr: 1.0000e-04
# Epoch 131/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.7270 - accuracy: 0.6844 - auc: 0.7519 - val_loss: 0.7057 - val_accuracy: 0.7208 - val_auc: 0.7699 - lr: 1.0000e-04
# Epoch 132/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7314 - accuracy: 0.6816 - auc: 0.7440 - val_loss: 0.7018 - val_accuracy: 0.7171 - val_auc: 0.7694 - lr: 1.0000e-04
# Epoch 133/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.7286 - accuracy: 0.6924 - auc: 0.7502 - val_loss: 0.7010 - val_accuracy: 0.7196 - val_auc: 0.7703 - lr: 1.0000e-04
# Epoch 134/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.7205 - accuracy: 0.6829 - auc: 0.7512 - val_loss: 0.7057 - val_accuracy: 0.7073 - val_auc: 0.7693 - lr: 1.0000e-04
# Epoch 135/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7250 - accuracy: 0.6918 - auc: 0.7479 - val_loss: 0.7002 - val_accuracy: 0.7220 - val_auc: 0.7692 - lr: 1.0000e-04
# Epoch 136/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7190 - accuracy: 0.6826 - auc: 0.7492 - val_loss: 0.6990 - val_accuracy: 0.7196 - val_auc: 0.7637 - lr: 1.0000e-04
# Epoch 137/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7215 - accuracy: 0.6807 - auc: 0.7478 - val_loss: 0.6937 - val_accuracy: 0.7171 - val_auc: 0.7720 - lr: 1.0000e-04
# Epoch 138/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7189 - accuracy: 0.6807 - auc: 0.7469 - val_loss: 0.6881 - val_accuracy: 0.7183 - val_auc: 0.7735 - lr: 1.0000e-04
# Epoch 139/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7171 - accuracy: 0.6915 - auc: 0.7483 - val_loss: 0.6911 - val_accuracy: 0.7122 - val_auc: 0.7692 - lr: 1.0000e-04
# Epoch 140/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.7166 - accuracy: 0.6899 - auc: 0.7461 - val_loss: 0.6835 - val_accuracy: 0.7196 - val_auc: 0.7720 - lr: 1.0000e-04
# Epoch 141/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7101 - accuracy: 0.6863 - auc: 0.7468 - val_loss: 0.6859 - val_accuracy: 0.7232 - val_auc: 0.7709 - lr: 1.0000e-04
# Epoch 142/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7026 - accuracy: 0.6909 - auc: 0.7550 - val_loss: 0.6812 - val_accuracy: 0.7196 - val_auc: 0.7733 - lr: 1.0000e-04
# Epoch 143/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7030 - accuracy: 0.6912 - auc: 0.7532 - val_loss: 0.6888 - val_accuracy: 0.7060 - val_auc: 0.7680 - lr: 1.0000e-04
# Epoch 144/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.7060 - accuracy: 0.6856 - auc: 0.7488 - val_loss: 0.6797 - val_accuracy: 0.7245 - val_auc: 0.7687 - lr: 1.0000e-04
# Epoch 145/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.6960 - accuracy: 0.6896 - auc: 0.7549 - val_loss: 0.6792 - val_accuracy: 0.7159 - val_auc: 0.7701 - lr: 1.0000e-04
# Epoch 146/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.7020 - accuracy: 0.6826 - auc: 0.7484 - val_loss: 0.6830 - val_accuracy: 0.7109 - val_auc: 0.7686 - lr: 1.0000e-04
# Epoch 147/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.6925 - accuracy: 0.6906 - auc: 0.7540 - val_loss: 0.6772 - val_accuracy: 0.7122 - val_auc: 0.7719 - lr: 1.0000e-04
# Epoch 148/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6997 - accuracy: 0.6816 - auc: 0.7461 - val_loss: 0.6831 - val_accuracy: 0.7183 - val_auc: 0.7668 - lr: 1.0000e-04
# Epoch 149/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6929 - accuracy: 0.6783 - auc: 0.7523 - val_loss: 0.6727 - val_accuracy: 0.7183 - val_auc: 0.7714 - lr: 1.0000e-04
# Epoch 150/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6957 - accuracy: 0.6813 - auc: 0.7513 - val_loss: 0.6691 - val_accuracy: 0.7183 - val_auc: 0.7707 - lr: 1.0000e-04
# Epoch 151/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6840 - accuracy: 0.6927 - auc: 0.7567 - val_loss: 0.6636 - val_accuracy: 0.7208 - val_auc: 0.7721 - lr: 1.0000e-04
# Epoch 152/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6882 - accuracy: 0.6798 - auc: 0.7549 - val_loss: 0.6636 - val_accuracy: 0.7097 - val_auc: 0.7720 - lr: 1.0000e-04
# Epoch 153/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6826 - accuracy: 0.6936 - auc: 0.7573 - val_loss: 0.6634 - val_accuracy: 0.7220 - val_auc: 0.7721 - lr: 1.0000e-04
# Epoch 154/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6802 - accuracy: 0.6979 - auc: 0.7595 - val_loss: 0.6651 - val_accuracy: 0.7134 - val_auc: 0.7705 - lr: 1.0000e-04
# Epoch 155/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6847 - accuracy: 0.6823 - auc: 0.7530 - val_loss: 0.6596 - val_accuracy: 0.7171 - val_auc: 0.7690 - lr: 1.0000e-04
# Epoch 156/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6743 - accuracy: 0.6946 - auc: 0.7602 - val_loss: 0.6603 - val_accuracy: 0.7183 - val_auc: 0.7725 - lr: 1.0000e-04
# Epoch 157/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6816 - accuracy: 0.6826 - auc: 0.7529 - val_loss: 0.6589 - val_accuracy: 0.7183 - val_auc: 0.7714 - lr: 1.0000e-04
# Epoch 158/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6760 - accuracy: 0.6875 - auc: 0.7588 - val_loss: 0.6551 - val_accuracy: 0.7257 - val_auc: 0.7732 - lr: 1.0000e-04
# Epoch 159/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.6757 - accuracy: 0.6964 - auc: 0.7544 - val_loss: 0.6570 - val_accuracy: 0.7109 - val_auc: 0.7688 - lr: 1.0000e-04
# Epoch 160/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6724 - accuracy: 0.6992 - auc: 0.7572 - val_loss: 0.6537 - val_accuracy: 0.7146 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 161/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6739 - accuracy: 0.6918 - auc: 0.7544 - val_loss: 0.6500 - val_accuracy: 0.7183 - val_auc: 0.7721 - lr: 1.0000e-04
# Epoch 162/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6642 - accuracy: 0.6982 - auc: 0.7640 - val_loss: 0.6517 - val_accuracy: 0.7171 - val_auc: 0.7722 - lr: 1.0000e-04
# Epoch 163/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6692 - accuracy: 0.6967 - auc: 0.7621 - val_loss: 0.6558 - val_accuracy: 0.7122 - val_auc: 0.7695 - lr: 1.0000e-04
# Epoch 164/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6708 - accuracy: 0.6859 - auc: 0.7567 - val_loss: 0.6485 - val_accuracy: 0.7232 - val_auc: 0.7727 - lr: 1.0000e-04
# Epoch 165/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6637 - accuracy: 0.6952 - auc: 0.7635 - val_loss: 0.6505 - val_accuracy: 0.7183 - val_auc: 0.7707 - lr: 1.0000e-04
# Epoch 166/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6578 - accuracy: 0.7035 - auc: 0.7659 - val_loss: 0.6465 - val_accuracy: 0.7208 - val_auc: 0.7733 - lr: 1.0000e-04
# Epoch 167/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6650 - accuracy: 0.7007 - auc: 0.7586 - val_loss: 0.6476 - val_accuracy: 0.7196 - val_auc: 0.7705 - lr: 1.0000e-04
# Epoch 168/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6598 - accuracy: 0.6924 - auc: 0.7578 - val_loss: 0.6417 - val_accuracy: 0.7159 - val_auc: 0.7723 - lr: 1.0000e-04
# Epoch 169/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6617 - accuracy: 0.6942 - auc: 0.7595 - val_loss: 0.6422 - val_accuracy: 0.7171 - val_auc: 0.7703 - lr: 1.0000e-04
# Epoch 170/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6518 - accuracy: 0.6955 - auc: 0.7624 - val_loss: 0.6414 - val_accuracy: 0.7134 - val_auc: 0.7725 - lr: 1.0000e-04
# Epoch 171/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6506 - accuracy: 0.7010 - auc: 0.7653 - val_loss: 0.6417 - val_accuracy: 0.7109 - val_auc: 0.7678 - lr: 1.0000e-04
# Epoch 172/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6554 - accuracy: 0.6912 - auc: 0.7647 - val_loss: 0.6397 - val_accuracy: 0.7196 - val_auc: 0.7696 - lr: 1.0000e-04
# Epoch 173/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6582 - accuracy: 0.6896 - auc: 0.7611 - val_loss: 0.6430 - val_accuracy: 0.7134 - val_auc: 0.7674 - lr: 1.0000e-04
# Epoch 174/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6516 - accuracy: 0.6893 - auc: 0.7644 - val_loss: 0.6388 - val_accuracy: 0.7220 - val_auc: 0.7739 - lr: 1.0000e-04
# Epoch 175/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6506 - accuracy: 0.6942 - auc: 0.7683 - val_loss: 0.6358 - val_accuracy: 0.7097 - val_auc: 0.7707 - lr: 1.0000e-04
# Epoch 176/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6541 - accuracy: 0.6952 - auc: 0.7593 - val_loss: 0.6360 - val_accuracy: 0.7220 - val_auc: 0.7668 - lr: 1.0000e-04
# Epoch 177/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6549 - accuracy: 0.6859 - auc: 0.7561 - val_loss: 0.6357 - val_accuracy: 0.7196 - val_auc: 0.7731 - lr: 1.0000e-04
# Epoch 178/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6472 - accuracy: 0.6955 - auc: 0.7604 - val_loss: 0.6346 - val_accuracy: 0.7134 - val_auc: 0.7716 - lr: 1.0000e-04
# Epoch 179/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6421 - accuracy: 0.7010 - auc: 0.7653 - val_loss: 0.6322 - val_accuracy: 0.7183 - val_auc: 0.7736 - lr: 1.0000e-04
# Epoch 180/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6433 - accuracy: 0.7022 - auc: 0.7654 - val_loss: 0.6411 - val_accuracy: 0.7171 - val_auc: 0.7676 - lr: 1.0000e-04
# Epoch 181/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6427 - accuracy: 0.6924 - auc: 0.7638 - val_loss: 0.6293 - val_accuracy: 0.7208 - val_auc: 0.7703 - lr: 1.0000e-04
# Epoch 182/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6357 - accuracy: 0.6982 - auc: 0.7684 - val_loss: 0.6284 - val_accuracy: 0.7208 - val_auc: 0.7716 - lr: 1.0000e-04
# Epoch 183/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6432 - accuracy: 0.6939 - auc: 0.7622 - val_loss: 0.6326 - val_accuracy: 0.7208 - val_auc: 0.7717 - lr: 1.0000e-04
# Epoch 184/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6436 - accuracy: 0.6933 - auc: 0.7586 - val_loss: 0.6233 - val_accuracy: 0.7196 - val_auc: 0.7722 - lr: 1.0000e-04
# Epoch 185/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6373 - accuracy: 0.6909 - auc: 0.7665 - val_loss: 0.6252 - val_accuracy: 0.7196 - val_auc: 0.7724 - lr: 1.0000e-04
# Epoch 186/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6341 - accuracy: 0.6998 - auc: 0.7684 - val_loss: 0.6305 - val_accuracy: 0.7257 - val_auc: 0.7713 - lr: 1.0000e-04
# Epoch 187/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6340 - accuracy: 0.6979 - auc: 0.7696 - val_loss: 0.6233 - val_accuracy: 0.7146 - val_auc: 0.7734 - lr: 1.0000e-04
# Epoch 188/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6339 - accuracy: 0.6982 - auc: 0.7676 - val_loss: 0.6241 - val_accuracy: 0.7183 - val_auc: 0.7721 - lr: 1.0000e-04
# Epoch 189/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6341 - accuracy: 0.6967 - auc: 0.7625 - val_loss: 0.6203 - val_accuracy: 0.7196 - val_auc: 0.7710 - lr: 1.0000e-04
# Epoch 190/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6295 - accuracy: 0.6946 - auc: 0.7674 - val_loss: 0.6243 - val_accuracy: 0.7183 - val_auc: 0.7706 - lr: 1.0000e-04
# Epoch 191/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6369 - accuracy: 0.6930 - auc: 0.7605 - val_loss: 0.6249 - val_accuracy: 0.7183 - val_auc: 0.7701 - lr: 1.0000e-04
# Epoch 192/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.6323 - accuracy: 0.6992 - auc: 0.7631 - val_loss: 0.6227 - val_accuracy: 0.7245 - val_auc: 0.7706 - lr: 1.0000e-04
# Epoch 193/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6303 - accuracy: 0.7019 - auc: 0.7658 - val_loss: 0.6253 - val_accuracy: 0.7171 - val_auc: 0.7710 - lr: 1.0000e-04
# Epoch 194/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6361 - accuracy: 0.7001 - auc: 0.7595 - val_loss: 0.6177 - val_accuracy: 0.7208 - val_auc: 0.7711 - lr: 1.0000e-04
# Epoch 195/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6270 - accuracy: 0.7019 - auc: 0.7679 - val_loss: 0.6218 - val_accuracy: 0.7196 - val_auc: 0.7716 - lr: 1.0000e-04
# Epoch 196/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6310 - accuracy: 0.6964 - auc: 0.7649 - val_loss: 0.6153 - val_accuracy: 0.7245 - val_auc: 0.7714 - lr: 1.0000e-04
# Epoch 197/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.6310 - accuracy: 0.6884 - auc: 0.7657 - val_loss: 0.6139 - val_accuracy: 0.7171 - val_auc: 0.7705 - lr: 1.0000e-04
# Epoch 198/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.6253 - accuracy: 0.7026 - auc: 0.7676 - val_loss: 0.6203 - val_accuracy: 0.7269 - val_auc: 0.7701 - lr: 1.0000e-04
# Epoch 199/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6198 - accuracy: 0.6992 - auc: 0.7724 - val_loss: 0.6156 - val_accuracy: 0.7245 - val_auc: 0.7716 - lr: 1.0000e-04
# Epoch 200/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.6181 - accuracy: 0.7032 - auc: 0.7718 - val_loss: 0.6227 - val_accuracy: 0.7183 - val_auc: 0.7694 - lr: 1.0000e-04
# Epoch 201/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6205 - accuracy: 0.7001 - auc: 0.7740 - val_loss: 0.6172 - val_accuracy: 0.7159 - val_auc: 0.7715 - lr: 1.0000e-04
# Epoch 202/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6201 - accuracy: 0.6982 - auc: 0.7642 - val_loss: 0.6187 - val_accuracy: 0.7232 - val_auc: 0.7680 - lr: 1.0000e-04
# Epoch 203/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6107 - accuracy: 0.7127 - auc: 0.7807 - val_loss: 0.6174 - val_accuracy: 0.7220 - val_auc: 0.7697 - lr: 1.0000e-05
# Epoch 204/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6174 - accuracy: 0.7069 - auc: 0.7674 - val_loss: 0.6164 - val_accuracy: 0.7208 - val_auc: 0.7703 - lr: 1.0000e-05
# Epoch 205/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6279 - accuracy: 0.6930 - auc: 0.7601 - val_loss: 0.6155 - val_accuracy: 0.7183 - val_auc: 0.7711 - lr: 1.0000e-05
# Epoch 206/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6182 - accuracy: 0.7056 - auc: 0.7722 - val_loss: 0.6149 - val_accuracy: 0.7196 - val_auc: 0.7706 - lr: 1.0000e-05
# Epoch 207/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.6183 - accuracy: 0.7035 - auc: 0.7767 - val_loss: 0.6147 - val_accuracy: 0.7196 - val_auc: 0.7718 - lr: 1.0000e-05

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy over epochs
plt.plot(history_GRU.history['accuracy'], label='Training Accuracy')
plt.plot(history_GRU.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation auc over epochs
plt.plot(history_GRU.history['auc'], label='Training Auc')
plt.plot(history_GRU.history['val_auc'], label='Validation Auc')
plt.xlabel('Epoch')
plt.ylabel('Auc')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history_GRU.history['loss'], label='Training Loss')
plt.plot(history_GRU.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##Evaluation

# %%
from sklearn.metrics import roc_auc_score

threshold = 0.5

y_train_pred = model.predict(x_train)
# Convert probabilities to binary predictions
y_train_pred_binary = (y_train_pred > threshold).astype(int)
y_valid_pred = model.predict(x_valid)
y_valid_pred_binary = (y_valid_pred > threshold).astype(int)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
accuracy_train = accuracy_score(y_train, y_train_pred_binary)
auc_train = roc_auc_score(y_train, y_train_pred)

accuracy_valid = accuracy_score(y_valid, y_valid_pred_binary)
auc_valid = roc_auc_score(y_valid, y_valid_pred)

print(f'Accuracy (train): {accuracy_train:.4f}')
print(f'AUC (train): {auc_train:.4f}')

print(f'Accuracy (valid): {accuracy_valid:.4f}')
print(f'AUC (valid): {auc_valid:.4f}')
# Out:
# 102/102 [==============================] - 2s 10ms/step
# 26/26 [==============================] - 0s 8ms/step
# Accuracy (train): 0.7106
# AUC (train): 0.7822
# Accuracy (valid): 0.7171
# AUC (valid): 0.7774

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
# Calculate precision, recall, and F1 score
precision = precision_score(y_train, y_train_pred_binary, zero_division=1)
recall = recall_score(y_train, y_train_pred_binary, zero_division=1)
f1 = f1_score(y_train, y_train_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For training set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4),"\n")

# Calculate precision, recall, and F1 score
precision = precision_score(y_valid, y_valid_pred_binary, zero_division=1)
recall = recall_score(y_valid, y_valid_pred_binary, zero_division=1)
f1 = f1_score(y_valid, y_valid_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For validation set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4))
# Out:
# For training set:
# Precision: 0.7493
# Recall: 0.6347
# F1 Score: 0.6873
#
# For validation set:
# Precision: 0.7357
# Recall: 0.67
# F1 Score: 0.7013

# %%
y_test_pred = model.predict(x_test)
#y_test_pred_binary = (y_test_pred > threshold).astype(int)
# Out:
# 92/92 [==============================] - 1s 9ms/step

# %%
# Assuming y_test_pred_binary is a numpy array
predictions_df = pd.DataFrame(y_test_pred, columns=['readmitted_within_30days'])
merged_df = test[['id']].merge(predictions_df, left_index=True, right_index=True)
merged_df.to_csv('Bi_GRU_Pred.csv', index=False)

from google.colab import files
files.download('Bi_GRU_Pred.csv')
