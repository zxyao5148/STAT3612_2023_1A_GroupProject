# %% [markdown]
# <a href="https://colab.research.google.com/github/zxyao5148/STAT3612_2023_1A_GroupProject/blob/main/RNN_Transformer/RNN_selected_feat_median.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Description:** This notebook demonstrates how to do timeseries classification using RNN models (Simple RNN, LSTM, and GRU).
#
# Reference: https://www.kaggle.com/code/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru/notebook

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd
import requests
from io import StringIO
import numpy as np

# Raw URLs for the CSV files
train_url = "https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/selected_feat/train_median.csv"
test_url = "https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/valid/selected_feat/valid_median.csv"

# Download the CSV files
train_csv = requests.get(train_url).text
test_csv = requests.get(test_url).text

# Read the CSV files into pandas DataFrames
train = pd.read_csv(StringIO(train_csv))
test = pd.read_csv(StringIO(test_csv))

# Split the data into features (X) and target variable (y)
#x_train = train.iloc[:, train.columns != train.columns[4]]  # Select all columns except the fourth one as features
x_train = train.iloc[:,5:]
y_train = train.iloc[:, 4]                                 # Select the fourth column as the target variable

#x_test = test.iloc[:, test.columns != test.columns[4]]     # Select all columns except the fourth one as features
x_test = test.iloc[:,5:]
y_test = test.iloc[:, 4]                                   # Select the fourth column as the target variable

# %%
x_train = x_train.values.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.values.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.

# %%
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, GRU, SimpleRNN
from keras.models import Sequential
from keras import optimizers
import keras

# %% [markdown]
# # Simple RNN

# %%
# Note: replace RNN with GRU or RNN if you want to try those
# In Keras, the "RNN" layer is a wrapper for the RNN cell, not the actual cell itself.
#specify the type of RNN cell to use, such as LSTM, GRU, or SimpleRNN

model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))
model.add(SimpleRNN(100, return_sequences=False, activation = "relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=["accuracy"])

print ('model compiled')

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

print (model.summary())

#Train the model
history_RNN=model.fit(x_train, y_train, batch_size=512, epochs=200, validation_data = (x_test, y_test), callbacks=callbacks)
# Out:
# model compiled
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100, 50)           2600
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 100)               15100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 17801 (69.54 KB)
# Trainable params: 17801 (69.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 19/19 [==============================] - 20s 222ms/step - loss: 0.4646 - accuracy: 0.8206 - val_loss: 0.4410 - val_accuracy: 0.8232
# Epoch 2/200
# 19/19 [==============================] - 3s 147ms/step - loss: 0.4320 - accuracy: 0.8270 - val_loss: 0.4332 - val_accuracy: 0.8215
# Epoch 3/200
# 19/19 [==============================] - 3s 160ms/step - loss: 0.4254 - accuracy: 0.8298 - val_loss: 0.4245 - val_accuracy: 0.8305
# Epoch 4/200
# 19/19 [==============================] - 4s 216ms/step - loss: 0.4190 - accuracy: 0.8322 - val_loss: 0.4231 - val_accuracy: 0.8301
# Epoch 5/200
# 19/19 [==============================] - 3s 153ms/step - loss: 0.4005 - accuracy: 0.8465 - val_loss: 0.4048 - val_accuracy: 0.8434
# Epoch 25/200
# 19/19 [==============================] - 4s 233ms/step - loss: 0.3966 - accuracy: 0.8462 - val_loss: 0.4051 - val_accuracy: 0.8417
# Epoch 26/200
# 19/19 [==============================] - 3s 164ms/step - loss: 0.3967 - accuracy: 0.8492 - val_loss: 0.3979 - val_accuracy: 0.8460
# Epoch 27/200
# 19/19 [==============================] - 3s 154ms/step - loss: 0.3966 - accuracy: 0.8466 - val_loss: 0.4038 - val_accuracy: 0.8473
# Epoch 28/200
# 19/19 [==============================] - 3s 151ms/step - loss: 0.3963 - accuracy: 0.8509 - val_loss: 0.4069 - val_accuracy: 0.8378
# Epoch 29/200
# 19/19 [==============================] - 4s 196ms/step - loss: 0.3986 - accuracy: 0.8482 - val_loss: 0.4036 - val_accuracy: 0.8456
# Epoch 30/200
# 19/19 [==============================] - 5s 234ms/step - loss: 0.3956 - accuracy: 0.8482 - val_loss: 0.4045 - val_accuracy: 0.8426
# Epoch 31/200
# 19/19 [==============================] - 3s 145ms/step - loss: 0.3959 - accuracy: 0.8490 - val_loss: 0.4084 - val_accuracy: 0.8409
# Epoch 32/200
# 19/19 [==============================] - 3s 157ms/step - loss: 0.3928 - accuracy: 0.8494 - val_loss: 0.4032 - val_accuracy: 0.8452
# Epoch 33/200
# 19/19 [==============================] - 3s 182ms/step - loss: 0.3926 - accuracy: 0.8508 - val_loss: 0.4111 - val_accuracy: 0.8426
# Epoch 34/200
# 19/19 [==============================] - 4s 214ms/step - loss: 0.3955 - accuracy: 0.8507 - val_loss: 0.3998 - val_accuracy: 0.8447
# Epoch 35/200
# 19/19 [==============================] - 3s 149ms/step - loss: 0.3902 - accuracy: 0.8499 - val_loss: 0.4023 - val_accuracy: 0.8422
# Epoch 36/200
# 19/19 [==============================] - 3s 145ms/step - loss: 0.3856 - accuracy: 0.8519 - val_loss: 0.4021 - val_accuracy: 0.8430

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy over epochs
plt.plot(history_RNN.history['accuracy'], label='Training Accuracy')
plt.plot(history_RNN.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history_RNN.history['loss'], label='Training Loss')
plt.plot(history_RNN.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##Evaluation

# %%
from sklearn.metrics import roc_auc_score

y_train_pred = model.predict(x_train)
# Convert probabilities to binary predictions
y_train_pred_binary = np.argmax(y_train_pred, axis=1) # Choose the class with the highest probability
y_test_pred = model.predict(x_test)
y_test_pred_binary = np.argmax(y_test_pred, axis=1)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
accuracy_train = accuracy_score(y_train, y_train_pred_binary)
auc_train = roc_auc_score(y_train, y_train_pred)

accuracy_test = accuracy_score(y_test, y_test_pred_binary)
auc_test = roc_auc_score(y_test, y_test_pred)

print(f'Accuracy (train): {accuracy_train:.4f}')
print(f'AUC (train): {auc_train:.4f}')

print(f'Accuracy (test): {accuracy_test:.4f}')
print(f'AUC (test): {auc_test:.4f}')
# Out:
# 290/290 [==============================] - 6s 21ms/step
# 73/73 [==============================] - 2s 28ms/step
# Accuracy (train): 0.8253
# AUC (train): 0.7542
# Accuracy (test): 0.8228
# AUC (test): 0.7377

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
# Calculate precision, recall, and F1 score
precision = precision_score(y_train, y_train_pred_binary, zero_division=1)
recall = recall_score(y_train, y_train_pred_binary, zero_division=1)
f1 = f1_score(y_train, y_train_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For training set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4),"\n")

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_test_pred_binary, zero_division=1)
recall = recall_score(y_test, y_test_pred_binary, zero_division=1)
f1 = f1_score(y_test, y_test_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For testing set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4))
# Out:
# For training set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0
#
# For testing set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0

# %% [markdown]
# # LSTM

# %%
model_LSTM = Sequential()
model_LSTM.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model_LSTM.add(Dropout(0.2))
model_LSTM.add(LSTM(100, return_sequences=False, activation="relu"))
model_LSTM.add(Dropout(0.2))
model_LSTM.add(Dense(1, activation="sigmoid"))  # Changed activation function

model_LSTM.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

print('model compiled')

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

print(model_LSTM.summary())

#Train the model
history_LSTM=model_LSTM.fit(x_train, y_train, batch_size=512, epochs=200, validation_data = (x_test, y_test), callbacks=callbacks)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# model compiled
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout_2 (Dropout)         (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100)               60400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 70901 (276.96 KB)
# Trainable params: 70901 (276.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 19/19 [==============================] - 9s 228ms/step - loss: 0.5615 - accuracy: 0.8249 - val_loss: 0.4982 - val_accuracy: 0.8228
# Epoch 2/200
# 19/19 [==============================] - 5s 270ms/step - loss: 0.4802 - accuracy: 0.8253 - val_loss: 0.4676 - val_accuracy: 0.8228
# Epoch 3/200
# 19/19 [==============================] - 3s 178ms/step - loss: 0.4683 - accuracy: 0.8253 - val_loss: 0.4663 - val_accuracy: 0.8228
# Epoch 4/200
# 19/19 [==============================] - 4s 186ms/step - loss: 0.4659 - accuracy: 0.8253 - val_loss: 0.4672 - val_accuracy: 0.8228
# Epoch 5/200
# 19/19 [==============================] - 7s 363ms/step - loss: 0.4678 - accuracy: 0.8253 - val_loss: 0.4668 - val_accuracy: 0.8228
# Epoch 6/200
# 19/19 [==============================] - 4s 224ms/step - loss: 0.4640 - accuracy: 0.8253 - val_loss: 0.4661 - val_accuracy: 0.8228
# Epoch 7/200
# 19/19 [==============================] - 3s 177ms/step - loss: 0.4647 - accuracy: 0.8253 - val_loss: 0.4686 - val_accuracy: 0.8228
# Epoch 8/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.4640 - accuracy: 0.8253 - val_loss: 0.4655 - val_accuracy: 0.8228
# Epoch 9/200
# 19/19 [==============================] - 4s 184ms/step - loss: 0.4620 - accuracy: 0.8253 - val_loss: 0.4639 - val_accuracy: 0.8228
# Epoch 10/200
# 19/19 [==============================] - 3s 171ms/step - loss: 0.4584 - accuracy: 0.8250 - val_loss: 0.4646 - val_accuracy: 0.8241
# 19/19 [==============================] - 3s 176ms/step - loss: 0.7011 - accuracy: 0.7690 - val_loss: 0.5440 - val_accuracy: 0.7953
# Epoch 68/200
# 19/19 [==============================] - 5s 282ms/step - loss: 0.5348 - accuracy: 0.8071 - val_loss: 0.4808 - val_accuracy: 0.8275
# Epoch 69/200
# 19/19 [==============================] - 3s 163ms/step - loss: 0.5053 - accuracy: 0.8179 - val_loss: 0.4810 - val_accuracy: 0.8280
# Epoch 70/200
# 19/19 [==============================] - 3s 174ms/step - loss: 0.4947 - accuracy: 0.8243 - val_loss: 0.4774 - val_accuracy: 0.8284
# Epoch 71/200
# 19/19 [==============================] - 4s 221ms/step - loss: 0.4924 - accuracy: 0.8247 - val_loss: 0.4762 - val_accuracy: 0.8262

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy over epochs
plt.plot(history_LSTM.history['accuracy'], label='Training Accuracy')
plt.plot(history_LSTM.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history_LSTM.history['loss'], label='Training Loss')
plt.plot(history_LSTM.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##Evaluation

# %%
from sklearn.metrics import roc_auc_score

y_train_pred = model_LSTM.predict(x_train)
# Convert probabilities to binary predictions
y_train_pred_binary = np.argmax(y_train_pred, axis=1) # Choose the class with the highest probability
y_test_pred = model_LSTM.predict(x_test)
y_test_pred_binary = np.argmax(y_test_pred, axis=1)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
accuracy_train = accuracy_score(y_train, y_train_pred_binary)
auc_train = roc_auc_score(y_train, y_train_pred)

accuracy_test = accuracy_score(y_test, y_test_pred_binary)
auc_test = roc_auc_score(y_test, y_test_pred)

print(f'Accuracy (train): {accuracy_train:.4f}')
print(f'AUC (train): {auc_train:.4f}')

print(f'Accuracy (test): {accuracy_test:.4f}')
print(f'AUC (test): {auc_test:.4f}')
# Out:
# 290/290 [==============================] - 6s 18ms/step
# 73/73 [==============================] - 1s 17ms/step
# Accuracy (train): 0.8253
# AUC (train): 0.7211
# Accuracy (test): 0.8228
# AUC (test): 0.7144

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
# Calculate precision, recall, and F1 score
precision = precision_score(y_train, y_train_pred_binary, zero_division=1)
recall = recall_score(y_train, y_train_pred_binary, zero_division=1)
f1 = f1_score(y_train, y_train_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For training set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4),"\n")

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_test_pred_binary, zero_division=1)
recall = recall_score(y_test, y_test_pred_binary, zero_division=1)
f1 = f1_score(y_test, y_test_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For testing set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4))
# Out:
# For training set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0
#
# For testing set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0

# %% [markdown]
# # GRU

# %%
model_GRU = Sequential()
model_GRU.add(GRU(50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model_GRU.add(Dropout(0.2))
model_GRU.add(GRU(64, return_sequences=False, activation='relu'))
model_GRU.add(Dropout(0.2))
model_GRU.add(Dense(1, activation = "sigmoid"))

model_GRU.compile(loss='binary_crossentropy', optimizer='Adam', metrics=["accuracy"])

print('model compiled')

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

print(model_GRU.summary())

#Train the model
history_GRU=model_GRU.fit(x_train, y_train, batch_size=512, epochs=200, validation_data = (x_test, y_test), callbacks=callbacks)
# Out:
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# model compiled
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 100, 50)           7950
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  gru_1 (GRU)                 (None, 64)                22272
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 30287 (118.31 KB)
# Trainable params: 30287 (118.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 19/19 [==============================] - 10s 288ms/step - loss: 0.5922 - accuracy: 0.7929 - val_loss: 0.4806 - val_accuracy: 0.8228
# Epoch 2/200
# 19/19 [==============================] - 4s 204ms/step - loss: 0.4822 - accuracy: 0.8253 - val_loss: 0.4771 - val_accuracy: 0.8228
# Epoch 3/200
# 19/19 [==============================] - 6s 305ms/step - loss: 0.4732 - accuracy: 0.8253 - val_loss: 0.4706 - val_accuracy: 0.8228
# Epoch 4/200
# 19/19 [==============================] - 4s 199ms/step - loss: 0.4683 - accuracy: 0.8253 - val_loss: 0.4679 - val_accuracy: 0.8228
# Epoch 5/200
# 19/19 [==============================] - 4s 204ms/step - loss: 0.4654 - accuracy: 0.8253 - val_loss: 0.4664 - val_accuracy: 0.8228
# Epoch 6/200
# 19/19 [==============================] - 5s 275ms/step - loss: 0.4638 - accuracy: 0.8253 - val_loss: 0.4648 - val_accuracy: 0.8228
# Epoch 7/200
# 19/19 [==============================] - 4s 223ms/step - loss: 0.4629 - accuracy: 0.8253 - val_loss: 0.4642 - val_accuracy: 0.8228
# Epoch 8/200
# 19/19 [==============================] - 4s 195ms/step - loss: 0.4588 - accuracy: 0.8253 - val_loss: 0.4632 - val_accuracy: 0.8228
# Epoch 9/200
# 19/19 [==============================] - 5s 258ms/step - loss: 0.4590 - accuracy: 0.8253 - val_loss: 0.4618 - val_accuracy: 0.8228
# Epoch 10/200
# 19/19 [==============================] - 5s 241ms/step - loss: 0.4562 - accuracy: 0.8253 - val_loss: 0.4613 - val_accuracy: 0.8228
# Epoch 11/200
# 19/19 [==============================] - 4s 204ms/step - loss: 0.4533 - accuracy: 0.8253 - val_loss: 0.4579 - val_accuracy: 0.8228
# Epoch 12/200
# 19/19 [==============================] - 4s 236ms/step - loss: 0.4506 - accuracy: 0.8253 - val_loss: 0.4538 - val_accuracy: 0.8228
# Epoch 13/200
# 19/19 [==============================] - 5s 272ms/step - loss: 0.4439 - accuracy: 0.8253 - val_loss: 0.4471 - val_accuracy: 0.8228
# Epoch 14/200
# 19/19 [==============================] - 4s 205ms/step - loss: 0.4371 - accuracy: 0.8253 - val_loss: 0.4411 - val_accuracy: 0.8228
# Epoch 15/200
# 19/19 [==============================] - 5s 241ms/step - loss: 0.4324 - accuracy: 0.8255 - val_loss: 0.4344 - val_accuracy: 0.8228
# Epoch 16/200
# 19/19 [==============================] - 5s 267ms/step - loss: 0.4256 - accuracy: 0.8264 - val_loss: 0.4258 - val_accuracy: 0.8275
# Epoch 17/200
# 19/19 [==============================] - 4s 205ms/step - loss: 0.4200 - accuracy: 0.8345 - val_loss: 0.4256 - val_accuracy: 0.8249
# Epoch 18/200
# 19/19 [==============================] - 6s 297ms/step - loss: 0.4193 - accuracy: 0.8373 - val_loss: 0.4258 - val_accuracy: 0.8262
# Epoch 78/200
# 19/19 [==============================] - 4s 207ms/step - loss: 0.3957 - accuracy: 0.8482 - val_loss: 0.4081 - val_accuracy: 0.8422
# Epoch 79/200
# 19/19 [==============================] - 4s 206ms/step - loss: 0.3962 - accuracy: 0.8506 - val_loss: 0.4071 - val_accuracy: 0.8452
# Epoch 80/200
# 19/19 [==============================] - 6s 322ms/step - loss: 0.3958 - accuracy: 0.8490 - val_loss: 0.4068 - val_accuracy: 0.8443
# Epoch 81/200
# 19/19 [==============================] - 4s 212ms/step - loss: 0.3959 - accuracy: 0.8496 - val_loss: 0.4048 - val_accuracy: 0.8447
# Epoch 82/200
# 19/19 [==============================] - 4s 211ms/step - loss: 0.3944 - accuracy: 0.8488 - val_loss: 0.4105 - val_accuracy: 0.8447
# Epoch 83/200
# 19/19 [==============================] - 6s 311ms/step - loss: 0.3948 - accuracy: 0.8503 - val_loss: 0.4102 - val_accuracy: 0.8404
# Epoch 84/200
# 19/19 [==============================] - 4s 209ms/step - loss: 0.3959 - accuracy: 0.8495 - val_loss: 0.4045 - val_accuracy: 0.8447

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy over epochs
plt.plot(history_GRU.history['accuracy'], label='Training Accuracy')
plt.plot(history_GRU.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history_GRU.history['loss'], label='Training Loss')
plt.plot(history_GRU.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##Evaluation

# %%
from sklearn.metrics import roc_auc_score

y_train_pred = model_GRU.predict(x_train)
# Convert probabilities to binary predictions
y_train_pred_binary = np.argmax(y_train_pred, axis=1) # Choose the class with the highest probability
y_test_pred = model_GRU.predict(x_test)
y_test_pred_binary = np.argmax(y_test_pred, axis=1)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
accuracy_train = accuracy_score(y_train, y_train_pred_binary)
auc_train = roc_auc_score(y_train, y_train_pred)

accuracy_test = accuracy_score(y_test, y_test_pred_binary)
auc_test = roc_auc_score(y_test, y_test_pred)

print(f'Accuracy (train): {accuracy_train:.4f}')
print(f'AUC (train): {auc_train:.4f}')

print(f'Accuracy (test): {accuracy_test:.4f}')
print(f'AUC (test): {auc_test:.4f}')
# Out:
# 290/290 [==============================] - 7s 24ms/step
# 73/73 [==============================] - 1s 19ms/step
# Accuracy (train): 0.8253
# AUC (train): 0.7369
# Accuracy (test): 0.8228
# AUC (test): 0.7248

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
# Calculate precision, recall, and F1 score
precision = precision_score(y_train, y_train_pred_binary, zero_division=1)
recall = recall_score(y_train, y_train_pred_binary, zero_division=1)
f1 = f1_score(y_train, y_train_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For training set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4),"\n")

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_test_pred_binary, zero_division=1)
recall = recall_score(y_test, y_test_pred_binary, zero_division=1)
f1 = f1_score(y_test, y_test_pred_binary, zero_division=1)

# Print with 4 digits limit
print("For testing set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4))
# Out:
# For training set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0
#
# For testing set:
# Precision: 1.0
# Recall: 0.0
# F1 Score: 0.0
