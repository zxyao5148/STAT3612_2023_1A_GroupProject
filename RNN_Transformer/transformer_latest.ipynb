# %% [markdown]
# <a href="https://colab.research.google.com/github/zxyao5148/STAT3612_2023_1A_GroupProject/blob/main/RNN_Transformer/transformer_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Timeseries classification with a Transformer model
#
# [Code source](https://keras.io/examples/timeseries/timeseries_classification_transformer/)<br>
# **Description:** This notebook demonstrates how to do timeseries classification using a Transformer model.

# %% [markdown]
# ## Introduction
#
# This is the Transformer architecture from
# [Attention Is All You Need](https://arxiv.org/abs/1706.03762),
# applied to timeseries instead of natural language.
#
# This example requires TensorFlow 2.4 or higher.
#
# ## Load the dataset
#
# We are going to use the same dataset and preprocessing as the
# [TimeSeries Classification from Scratch](https://keras.io/examples/timeseries/timeseries_classification_from_scratch)
# example.

# %%
import pandas as pd
import requests
from io import StringIO
import numpy as np
from sklearn.model_selection import train_test_split

# Raw URLs for the CSV files
train_url = "https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/train/train_valid_latest.csv"
test_url = "https://raw.githubusercontent.com/zxyao5148/STAT3612_2023_1A_GroupProject/main/data_processing/test/test_latest.csv"

# Download the CSV files
train_csv = requests.get(train_url).text
test_csv = requests.get(test_url).text

# Read the CSV files into pandas DataFrames
train = pd.read_csv(StringIO(train_csv))
test = pd.read_csv(StringIO(test_csv))

train['deathtime'] = np.where(train['deathtime'].notnull(), 1, 0)
test['deathtime'] = np.where(test['deathtime'].notnull(), 1, 0)

# Split the data into features (X) and target variable (y)
x_train = train[['deathtime']].join(train.iloc[:, 9:])
y_train = train.iloc[:, 8]

x_test = test[['deathtime']].join(test.iloc[:,8:])

# %%
x_train = x_train.values.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.values.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

# Reset the index of the y_train DataFrame
y_train = y_train.reset_index(drop=True)

# Shuffle the indices
idx = np.random.permutation(len(x_train))

# Reassign the values using the shuffled indices
x_train = x_train[idx]
y_train = y_train.iloc[idx]

# %%
train
# Out:
#                       id  subject_id   hadm_id            admittime  \
# 0      17195991_23542772    17195991  23542772  2110-01-11 22:47:00
# 1      13721591_20342223    13721591  20342223  2110-02-09 18:13:00
# 2      10582595_20690213    10582595  20690213  2110-02-09 20:41:00
# 3      14385035_20480421    14385035  20480421  2110-02-23 14:28:00
# 4      19170541_22178312    19170541  22178312  2110-02-28 21:48:00
# ...                  ...         ...       ...                  ...
# 11591  19508874_28498140    19508874  28498140  2207-04-29 16:20:00
# 11592  13364829_26673737    13364829  26673737  2207-12-15 20:42:00
# 11593  14434519_22141373    14434519  22141373  2207-12-25 15:35:00
# 11594  15888895_21231897    15888895  21231897  2208-01-13 06:54:00
# 11595  15211528_29711727    15211528  29711727  2208-02-07 18:31:00
#
#                  dischtime  deathtime   StudyDate   StudyTime  \
# 0      2110-01-18 10:25:00          0  2110-01-16   90654.546
# 1      2110-02-22 20:51:00          0  2110-02-19   41948.468
# 2      2110-02-17 15:40:00          0  2110-02-16   50133.578
# 3      2110-03-11 17:29:00          0  2110-02-28  214324.437
# 4      2110-03-12 17:47:00          0  2110-03-11   81842.812
# ...                    ...        ...         ...         ...
# 11591  2207-05-06 16:08:00          0  2207-05-03   35201.421
# 11592  2208-01-13 19:15:00          0  2208-01-08  161351.843
# 11593  2207-12-31 16:44:00          0  2207-12-30   80953.312
# 11594  2208-01-29 16:05:00          0  2208-01-27   83559.671
# 11595  2208-02-16 18:35:00          0  2208-02-12  112009.484
#
#        readmitted_within_30days  stay_len  ...  CARDIAC DRUGS  \
# 0                             0 -0.426682  ...      -0.377606
# 1                             0 -0.025023  ...      -0.377606
# 2                             0 -0.369302  ...       0.535389
# 3                             0  0.147116  ...       0.991886
# 4                             0 -0.139783  ...      -0.377606
# ...                         ...       ...  ...            ...
# 11591                         0 -0.426682  ...      -0.377606
# 11592                         1  0.835675  ...      -0.377606
# 11593                         0 -0.426682  ...      -0.377606
# 11594                         0  0.147116  ...       5.100364
# 11595                         0 -0.254543  ...      -0.377606
#
#        PRE-NATAL VITAMINS  ANESTHETICS  ANTIBIOTICS  ANTIHYPERGLYCEMICS  \
# 0               -0.015166    -0.464590    -0.455345           -0.324132
# 1               -0.015166     0.215206    -0.131328           -0.237590
# 2               -0.015166     3.614190     0.192689           -0.324132
# 3               -0.015166    -0.464590     0.840724            0.022039
# 4               -0.015166     0.215206    -0.293337           -0.324132
# ...                   ...          ...          ...                 ...
# 11591           -0.015166    -0.464590    -0.131328            0.195124
# 11592           -0.015166    -0.464590     0.354698            0.108581
# 11593           -0.015166    -0.464590    -0.779363           -0.324132
# 11594           -0.015166     0.895003    -0.617354           -0.324132
# 11595           -0.015166    -0.464590    -0.293337           -0.324132
#
#        SEDATIVE/HYPNOTICS  ANTIDOTES  AUTONOMIC DRUGS  VITAMINS  BIOLOGICALS
# 0               -0.428107  -0.047867         2.207636 -0.380706    -0.304657
# 1               -0.428107  -0.047867        -0.305346 -0.380706    -0.304657
# 2               -0.065138  -0.047867        -0.305346 -0.380706    -0.304657
# 3               -0.428107  -0.047867        -0.305346 -0.380706     1.551782
# 4               -0.428107  -0.047867        -0.305346 -0.380706    -0.304657
# ...                   ...        ...              ...       ...          ...
# 11591           -0.428107  -0.047867        -0.305346  0.718017     1.551782
# 11592            2.838614  -0.047867        -0.305346  4.014184    -0.304657
# 11593           -0.428107  -0.047867        -0.305346 -0.380706    -0.304657
# 11594           -0.428107  -0.047867        -0.305346 -0.380706    -0.304657
# 11595           -0.428107  -0.047867        -0.305346 -0.380706     1.551782
#
# [11596 rows x 164 columns]

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.
#
# You can replace your classification RNN layers with this one: the
# inputs are fully compatible!

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# We include residual connections, layer normalization, and dropout.
# The resulting layer can be stacked multiple times.
#
# The projection layers are implemented through `keras.layers.Conv1D`.

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %% [markdown]
# The main part of our model is now complete. We can stack multiple of those
# `transformer_encoder` blocks and we can also proceed to add the final
# Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
# layers, we need to reduce the output tensor of the `TransformerEncoder` part of
# our model down to a vector of features for each data point in the current
# batch. A common way to achieve this is to use a pooling layer. For
# this example, a `GlobalAveragePooling1D` layer is sufficient.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Train

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

history=model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 156, 1)]             0         []
#
#  layer_normalization (Layer  (None, 156, 1)               2         ['input_1[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 156, 1)               7169      ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout (Dropout)           (None, 156, 1)               0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 156, 1)               0         ['dropout[0][0]',
#  Lambda)                                                             'input_1[0][0]']
#
#  layer_normalization_1 (Lay  (None, 156, 1)               2         ['tf.__operators__.add[0][0]']
#  erNormalization)
#
#  conv1d (Conv1D)             (None, 156, 4)               8         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 156, 4)               0         ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 156, 1)               5         ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 156, 1)               0         ['conv1d_1[0][0]',
#  OpLambda)                                                           'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_1 (Mu  (None, 156, 1)               7169      ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  dropout_2 (Dropout)         (None, 156, 1)               0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 156, 1)               0         ['dropout_2[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  layer_normalization_3 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_2 (Conv1D)           (None, 156, 4)               8         ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 156, 4)               0         ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 156, 1)               5         ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 156, 1)               0         ['conv1d_3[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  layer_normalization_4 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_2 (Mu  (None, 156, 1)               7169      ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 156, 1)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_4 (TF  (None, 156, 1)               0         ['dropout_4[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  layer_normalization_5 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_4[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_4 (Conv1D)           (None, 156, 4)               8         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 156, 4)               0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 156, 1)               5         ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 156, 1)               0         ['conv1d_5[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  layer_normalization_6 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_5[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_3 (Mu  (None, 156, 1)               7169      ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 156, 1)               0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 156, 1)               0         ['dropout_6[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  layer_normalization_7 (Lay  (None, 156, 1)               2         ['tf.__operators__.add_6[0][0]
#  erNormalization)                                                   ']
#
#  conv1d_6 (Conv1D)           (None, 156, 4)               8         ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 156, 4)               0         ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 156, 1)               5         ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 156, 1)               0         ['conv1d_7[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  global_average_pooling1d (  (None, 156)                  0         ['tf.__operators__.add_7[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dense (Dense)               (None, 128)                  20096     ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 2)                    258       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 49098 (191.79 KB)
# Trainable params: 49098 (191.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 145/145 [==============================] - 45s 101ms/step - loss: 0.5121 - sparse_categorical_accuracy: 0.7982 - val_loss: 0.4453 - val_sparse_categorical_accuracy: 0.8237
# Epoch 2/200
# 145/145 [==============================] - 14s 98ms/step - loss: 0.4614 - sparse_categorical_accuracy: 0.8188 - val_loss: 0.4157 - val_sparse_categorical_accuracy: 0.8293
# Epoch 3/200
# 145/145 [==============================] - 14s 98ms/step - loss: 0.4323 - sparse_categorical_accuracy: 0.8237 - val_loss: 0.3911 - val_sparse_categorical_accuracy: 0.8345
# Epoch 4/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.4049 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.3758 - val_sparse_categorical_accuracy: 0.8379
# Epoch 5/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.3910 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.3629 - val_sparse_categorical_accuracy: 0.8500
# Epoch 6/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.3718 - sparse_categorical_accuracy: 0.8553 - val_loss: 0.3523 - val_sparse_categorical_accuracy: 0.8582
# Epoch 7/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3743 - sparse_categorical_accuracy: 0.8576 - val_loss: 0.3440 - val_sparse_categorical_accuracy: 0.8664
# Epoch 8/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3575 - sparse_categorical_accuracy: 0.8661 - val_loss: 0.3340 - val_sparse_categorical_accuracy: 0.8750
# Epoch 9/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3417 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.3250 - val_sparse_categorical_accuracy: 0.8918
# Epoch 10/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3356 - sparse_categorical_accuracy: 0.8842 - val_loss: 0.3167 - val_sparse_categorical_accuracy: 0.9004
# Epoch 11/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.8909 - val_loss: 0.3109 - val_sparse_categorical_accuracy: 0.9017
# Epoch 12/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3236 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3039 - val_sparse_categorical_accuracy: 0.9099
# Epoch 13/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3119 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.2978 - val_sparse_categorical_accuracy: 0.9147
# Epoch 14/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.3107 - sparse_categorical_accuracy: 0.9058 - val_loss: 0.2959 - val_sparse_categorical_accuracy: 0.9142
# Epoch 15/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.2908 - val_sparse_categorical_accuracy: 0.9172
# Epoch 16/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2985 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.2877 - val_sparse_categorical_accuracy: 0.9168
# Epoch 17/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2902 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.2839 - val_sparse_categorical_accuracy: 0.9198
# Epoch 18/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2841 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.2797 - val_sparse_categorical_accuracy: 0.9216
# Epoch 19/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2820 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.2763 - val_sparse_categorical_accuracy: 0.9220
# Epoch 20/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2784 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.2743 - val_sparse_categorical_accuracy: 0.9233
# Epoch 21/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2765 - sparse_categorical_accuracy: 0.9236 - val_loss: 0.2726 - val_sparse_categorical_accuracy: 0.9237
# Epoch 22/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2717 - sparse_categorical_accuracy: 0.9255 - val_loss: 0.2680 - val_sparse_categorical_accuracy: 0.9241
# Epoch 23/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2697 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.2683 - val_sparse_categorical_accuracy: 0.9246
# Epoch 24/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2643 - sparse_categorical_accuracy: 0.9274 - val_loss: 0.2668 - val_sparse_categorical_accuracy: 0.9254
# Epoch 25/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2632 - sparse_categorical_accuracy: 0.9273 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.9254
# Epoch 26/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2634 - sparse_categorical_accuracy: 0.9257 - val_loss: 0.2632 - val_sparse_categorical_accuracy: 0.9259
# Epoch 27/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2583 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.2620 - val_sparse_categorical_accuracy: 0.9263
# Epoch 28/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2553 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.2601 - val_sparse_categorical_accuracy: 0.9254
# Epoch 29/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2528 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.2601 - val_sparse_categorical_accuracy: 0.9272
# Epoch 30/200
# 145/145 [==============================] - 15s 105ms/step - loss: 0.2606 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.2592 - val_sparse_categorical_accuracy: 0.9272
# Epoch 31/200
# 145/145 [==============================] - 15s 103ms/step - loss: 0.2507 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.2562 - val_sparse_categorical_accuracy: 0.9259
# Epoch 32/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.2558 - val_sparse_categorical_accuracy: 0.9263
# Epoch 33/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2488 - sparse_categorical_accuracy: 0.9308 - val_loss: 0.2548 - val_sparse_categorical_accuracy: 0.9259
# Epoch 34/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2476 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.2544 - val_sparse_categorical_accuracy: 0.9267
# Epoch 35/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2424 - sparse_categorical_accuracy: 0.9318 - val_loss: 0.2535 - val_sparse_categorical_accuracy: 0.9259
# Epoch 36/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9305 - val_loss: 0.2525 - val_sparse_categorical_accuracy: 0.9272
# Epoch 37/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2429 - sparse_categorical_accuracy: 0.9314 - val_loss: 0.2525 - val_sparse_categorical_accuracy: 0.9280
# Epoch 38/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.9305 - val_loss: 0.2514 - val_sparse_categorical_accuracy: 0.9272
# Epoch 39/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2453 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.2517 - val_sparse_categorical_accuracy: 0.9276
# Epoch 40/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2373 - sparse_categorical_accuracy: 0.9314 - val_loss: 0.2507 - val_sparse_categorical_accuracy: 0.9280
# Epoch 41/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2390 - sparse_categorical_accuracy: 0.9310 - val_loss: 0.2509 - val_sparse_categorical_accuracy: 0.9280
# Epoch 42/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2381 - sparse_categorical_accuracy: 0.9327 - val_loss: 0.2502 - val_sparse_categorical_accuracy: 0.9280
# Epoch 43/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2389 - sparse_categorical_accuracy: 0.9321 - val_loss: 0.2501 - val_sparse_categorical_accuracy: 0.9272
# Epoch 44/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2388 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.2510 - val_sparse_categorical_accuracy: 0.9280
# Epoch 45/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2354 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.2493 - val_sparse_categorical_accuracy: 0.9284
# Epoch 46/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2331 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.2497 - val_sparse_categorical_accuracy: 0.9280
# Epoch 47/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2372 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.2487 - val_sparse_categorical_accuracy: 0.9280
# Epoch 48/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2350 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.2497 - val_sparse_categorical_accuracy: 0.9280
# Epoch 49/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2314 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.9280
# Epoch 50/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9334 - val_loss: 0.2486 - val_sparse_categorical_accuracy: 0.9284
# Epoch 51/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2311 - sparse_categorical_accuracy: 0.9322 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.9289
# Epoch 52/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2315 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.2481 - val_sparse_categorical_accuracy: 0.9289
# Epoch 53/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2297 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.2490 - val_sparse_categorical_accuracy: 0.9289
# Epoch 54/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2247 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.2477 - val_sparse_categorical_accuracy: 0.9284
# Epoch 55/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2275 - sparse_categorical_accuracy: 0.9334 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.9284
# Epoch 56/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2255 - sparse_categorical_accuracy: 0.9331 - val_loss: 0.2481 - val_sparse_categorical_accuracy: 0.9280
# Epoch 57/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2267 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2477 - val_sparse_categorical_accuracy: 0.9289
# Epoch 58/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2258 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.2500 - val_sparse_categorical_accuracy: 0.9289
# Epoch 59/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2271 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.2481 - val_sparse_categorical_accuracy: 0.9289
# Epoch 60/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2221 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2477 - val_sparse_categorical_accuracy: 0.9289
# Epoch 61/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2247 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.2482 - val_sparse_categorical_accuracy: 0.9289
# Epoch 62/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2259 - sparse_categorical_accuracy: 0.9339 - val_loss: 0.2486 - val_sparse_categorical_accuracy: 0.9293
# Epoch 63/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2252 - sparse_categorical_accuracy: 0.9339 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.9284
# Epoch 64/200
# 145/145 [==============================] - 15s 101ms/step - loss: 0.2244 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2487 - val_sparse_categorical_accuracy: 0.9293
# Epoch 65/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2225 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.2478 - val_sparse_categorical_accuracy: 0.9289
# Epoch 66/200
# 145/145 [==============================] - 15s 100ms/step - loss: 0.2218 - sparse_categorical_accuracy: 0.9335 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9280
# Epoch 67/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2204 - sparse_categorical_accuracy: 0.9353 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9289
# Epoch 68/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2207 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.9284
# Epoch 69/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2213 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9289
# Epoch 70/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2212 - sparse_categorical_accuracy: 0.9342 - val_loss: 0.2474 - val_sparse_categorical_accuracy: 0.9289
# Epoch 71/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2180 - sparse_categorical_accuracy: 0.9351 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.9289
# Epoch 72/200
# 145/145 [==============================] - 14s 99ms/step - loss: 0.2203 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.2475 - val_sparse_categorical_accuracy: 0.9289
# Epoch 73/200
# 145/145 [==============================] - 14s 100ms/step - loss: 0.2196 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.2479 - val_sparse_categorical_accuracy: 0.9289

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy over epochs
plt.plot(history.history['sparse_categorical_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
from sklearn.metrics import roc_auc_score

y_train_pred = model.predict(x_train)
# Convert probabilities to binary predictions
y_train_pred_binary = np.argmax(y_train_pred, axis=1) # Choose the class with the highest probability
# Out:
# 363/363 [==============================] - 7s 17ms/step

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
accuracy_train = accuracy_score(y_train, y_train_pred_binary)
auc_train = roc_auc_score(y_train, y_train_pred[:, 1])

print(f'Accuracy (train): {accuracy_train:.4f}')
print(f'AUC (train): {auc_train:.4f}')
# Out:
# Accuracy (train): 0.9336
# AUC (train): 0.8969

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
# Calculate precision, recall, and F1 score
precision = precision_score(y_train, y_train_pred_binary)
recall = recall_score(y_train, y_train_pred_binary)
f1 = f1_score(y_train, y_train_pred_binary)

# Print with 4 digits limit
print("For training set:")
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4),"\n")
# Out:
# For training set:
# Precision: 0.9961
# Recall: 0.6235
# F1 Score: 0.7669

# %% [markdown]
# ## Export prediction

# %%
y_test_pred = model.predict(x_test)
y_test_pred_binary = np.argmax(y_test_pred, axis=1)
# Out:
# 92/92 [==============================] - 2s 17ms/step

# %%
# Assuming y_test_pred_binary is a numpy array
predictions_df = pd.DataFrame(y_test_pred_binary, columns=['readmitted_within_30days'])
merged_df = test[['id']].merge(predictions_df, left_index=True, right_index=True)
merged_df.to_csv('predictions.csv', index=False)

from google.colab import files
files.download('predictions.csv')
